# %%
from weather import getHistoricalWeather
data = getHistoricalWeather()
# before doing this
# create a database named weather
from sqlalchemy import create_engine
user="root"
password = ""
port = "3306"
host="127.0.0.1"
database = "weather"
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}", echo=True)
engine.connect()
from sqlalchemy import Column, Date, Integer, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
class Date(Base):
    __tablename__ = 'date' # 表的名字

    # 定义各字段
    id = Column(Integer, primary_key=True, autoincrement=True)
    date = Column(String(32), unique=True)
    # main
    temperature = Column(String(32), default="0")
    feelsLike = Column(String(32), default="0")
    pressure = Column(String(32), default="0")
    humidity= Column(String(32), default="0")
    minTemperature=Column(String(32), default="0")
    maxTemperature=Column(String(32), default="0")
    
    wind_speed = Column(String(32), default="0")
    wind_deg = Column(String(32), default="0")
    wind_gust=Column(String(32), default="0")
    
    clouds = Column(String(32), default="0")
    
    weather_id=Column(String(32), default="0")
    weather_main=Column(String(32), default="None")
    weather_description=Column(String(32), default="None")
    weather_icon=Column(String(32), default="None")
    def __str__(self):
        return self.id

Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(engine)
date_list = data["list"]
for day in date_list:
    date= day["dt"]
    temperature = day["main"]["temp"]
    feelslike = day["main"]["feels_like"]
    pressure = day["main"]["pressure"]
    humidity = day["main"]["humidity"]
    temp_min = day["main"]["temp_min"]
    temp_max = day["main"]["temp_max"]
    
    wind_speed = day["wind"]["speed"]
    wind_deg = day["wind"]["deg"]
    wind_gust = day["wind"]["gust"]
    
    clouds = day["clouds"]["all"]
    
    weather_id = day["weather"][0]["id"]
    weather_main = day["weather"][0]["main"]
    weather_description = day["weather"][0]["description"]
    weather_icon = day["weather"][0]["icon"]
    
    db_session = Session()
    
    
    row = Date(
    date = date,
    temperature = temperature,
    feelsLike = feelslike,
    pressure = pressure,
    humidity= humidity,
    minTemperature=temp_min,
    maxTemperature=temp_max,
    
    wind_speed = wind_speed,
    wind_deg = wind_deg,
    wind_gust=wind_gust,
    
    clouds = clouds,
    
    weather_id=weather_id,
    weather_main=weather_main,
    weather_description=weather_description,
    weather_icon=weather_icon,
    )
    db_session.add(row)
    db_session.commit()
# db_session = Session()
# row = User(date="3")
# db_session.add(row)
# db_session.commit()
# Out:
# 2022-06-11 18:39:46,618 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2022-06-11 18:39:46,619 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-11 18:39:46,632 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2022-06-11 18:39:46,633 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# 2022-06-11 18:39:46,642 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-06-11 18:39:46,642 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-11 18:39:46,771 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,772 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-06-11 18:39:46,772 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {'table_schema': 'weather', 'table_name': 'date'}
# 2022-06-11 18:39:46,782 INFO sqlalchemy.engine.Engine
# DROP TABLE date
# 2022-06-11 18:39:46,785 INFO sqlalchemy.engine.Engine [no key 0.00224s] {}
# 2022-06-11 18:39:46,812 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,813 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,814 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-06-11 18:39:46,815 INFO sqlalchemy.engine.Engine [cached since 0.04322s ago] {'table_schema': 'weather', 'table_name': 'date'}
# 2022-06-11 18:39:46,817 INFO sqlalchemy.engine.Engine
# CREATE TABLE date (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	date VARCHAR(32),
# 	temperature VARCHAR(32),
# 	`feelsLike` VARCHAR(32),
# 	pressure VARCHAR(32),
# 	humidity VARCHAR(32),
# 	`minTemperature` VARCHAR(32),
# 	`maxTemperature` VARCHAR(32),
# 	wind_speed VARCHAR(32),
# 	wind_deg VARCHAR(32),
# 	wind_gust VARCHAR(32),
# 	clouds VARCHAR(32),
# 	weather_id VARCHAR(32),
# 	weather_main VARCHAR(32),
# 	weather_description VARCHAR(32),
# 	weather_icon VARCHAR(32),
# 	PRIMARY KEY (id),
# 	UNIQUE (date)
# )
#
#
# 2022-06-11 18:39:46,818 INFO sqlalchemy.engine.Engine [no key 0.00058s] {}
# 2022-06-11 18:39:46,826 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,829 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,831 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,831 INFO sqlalchemy.engine.Engine [generated in 0.00066s] {'date': 1654927200, 'temperature': 289.18, 'feelsLike': 289.16, 'pressure': 1019, 'humidity': 89, 'minTemperature': 288.18, 'maxTemperature': 290.36, 'wind_speed': 7.39, 'wind_deg': 231, 'wind_gust': 11.35, 'clouds': 0, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,835 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,838 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,838 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,839 INFO sqlalchemy.engine.Engine [cached since 0.00812s ago] {'date': 1654930800, 'temperature': 290.8, 'feelsLike': 290.66, 'pressure': 1020, 'humidity': 78, 'minTemperature': 289.85, 'maxTemperature': 292.03, 'wind_speed': 7.38, 'wind_deg': 248, 'wind_gust': 10.08, 'clouds': 0, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,841 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,842 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,843 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,843 INFO sqlalchemy.engine.Engine [cached since 0.01234s ago] {'date': 1654934400, 'temperature': 291.66, 'feelsLike': 291.84, 'pressure': 1020, 'humidity': 87, 'minTemperature': 290.92, 'maxTemperature': 293.14, 'wind_speed': 7.2, 'wind_deg': 251, 'wind_gust': 9.43, 'clouds': 2, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,845 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,848 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,848 INFO sqlalchemy.engine.Engine [cached since 0.01754s ago] {'date': 1654938000, 'temperature': 293.21, 'feelsLike': 293.02, 'pressure': 1020, 'humidity': 67, 'minTemperature': 291.14, 'maxTemperature': 294.24, 'wind_speed': 7.19, 'wind_deg': 250, 'wind_gust': 9.74, 'clouds': 1, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,852 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,855 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,855 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,856 INFO sqlalchemy.engine.Engine [cached since 0.02497s ago] {'date': 1654941600, 'temperature': 293.28, 'feelsLike': 293.05, 'pressure': 1021, 'humidity': 65, 'minTemperature': 292.07, 'maxTemperature': 294.31, 'wind_speed': 7.38, 'wind_deg': 252, 'wind_gust': 9.79, 'clouds': 1, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,857 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,858 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,859 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,859 INFO sqlalchemy.engine.Engine [cached since 0.02863s ago] {'date': 1654945200, 'temperature': 293.72, 'feelsLike': 293.53, 'pressure': 1021, 'humidity': 65, 'minTemperature': 292.58, 'maxTemperature': 295.42, 'wind_speed': 7.29, 'wind_deg': 255, 'wind_gust': 9.66, 'clouds': 1, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,861 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,864 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,864 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,865 INFO sqlalchemy.engine.Engine [cached since 0.03431s ago] {'date': 1654948800, 'temperature': 294, 'feelsLike': 293.81, 'pressure': 1021, 'humidity': 64, 'minTemperature': 293.14, 'maxTemperature': 294.81, 'wind_speed': 6.94, 'wind_deg': 256, 'wind_gust': 9.27, 'clouds': 1, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,867 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,868 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,870 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,871 INFO sqlalchemy.engine.Engine [cached since 0.04003s ago] {'date': 1654952400, 'temperature': 294.2, 'feelsLike': 294.03, 'pressure': 1021, 'humidity': 64, 'minTemperature': 292.14, 'maxTemperature': 295.98, 'wind_speed': 6.78, 'wind_deg': 257, 'wind_gust': 9.14, 'clouds': 0, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,872 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,874 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,876 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,878 INFO sqlalchemy.engine.Engine [cached since 0.04729s ago] {'date': 1654956000, 'temperature': 294.19, 'feelsLike': 294.02, 'pressure': 1021, 'humidity': 64, 'minTemperature': 293.7, 'maxTemperature': 295.42, 'wind_speed': 6.69, 'wind_deg': 259, 'wind_gust': 8.97, 'clouds': 1, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,880 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-11 18:39:46,883 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-11 18:39:46,885 INFO sqlalchemy.engine.Engine INSERT INTO date (date, temperature, `feelsLike`, pressure, humidity, `minTemperature`, `maxTemperature`, wind_speed, wind_deg, wind_gust, clouds, weather_id, weather_main, weather_description, weather_icon) VALUES (%(date)s, %(temperature)s, %(feelsLike)s, %(pressure)s, %(humidity)s, %(minTemperature)s, %(maxTemperature)s, %(wind_speed)s, %(wind_deg)s, %(wind_gust)s, %(clouds)s, %(weather_id)s, %(weather_main)s, %(weather_description)s, %(weather_icon)s)
# 2022-06-11 18:39:46,885 INFO sqlalchemy.engine.Engine [cached since 0.05476s ago] {'date': 1654959600, 'temperature': 294.42, 'feelsLike': 294.12, 'pressure': 1021, 'humidity': 58, 'minTemperature': 293.14, 'maxTemperature': 295.98, 'wind_speed': 6.66, 'wind_deg': 258, 'wind_gust': 8.85, 'clouds': 0, 'weather_id': 800, 'weather_main': 'Clear', 'weather_description': 'clear sky', 'weather_icon': '01d'}
# 2022-06-11 18:39:46,887 INFO sqlalchemy.engine.Engine COMMIT
